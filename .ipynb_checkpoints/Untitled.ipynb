# %%
1+4
# Out:
# 5

# %%
import numpy as np

# %%
import numpy as np
np.array([ 1, 2 , 5 ,10 ])
# Out:
# array([ 1,  2,  5, 10])

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Syed arman\OneDrive\Desktop\notebookk
